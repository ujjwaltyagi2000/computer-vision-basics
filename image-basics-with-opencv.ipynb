# %% [markdown]
# # **Image Basics with OpenCV**

# %% [markdown]
# * OpenCV: Open Source Computer Vision library
# * OpenCV is the huge open-source library for the computer vision, machine learning, and image processing and now it plays a major role in real-time operation which is very important in today’s systems.
# * By using it, one can process images and videos to identify objects, faces, or even handwriting of a human.
# * When it integrated with various libraries, such as NumPy, python is capable of processing the OpenCV array structure for analysis. To Identify image pattern and its various features we use vector space and perform mathematical operations on these features.
# * Created by Intel in 1999, written in C++ (we'll use its Python binding)

# %% [markdown]
# # Opening Image files

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
#The above line after "%" is only written for Jupyter notebook

# %%
import cv2

# %%
img = cv2.imread('jared.jpg')
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# This function reads an image directly as numpy array.
# One problem with this line is that even if the path is wrong, this line doesn't show an error.

# %%
img2 = cv2.imread('fake/path/wrong_img.jpg')

# %% [markdown]
# As you can see it doesn't show any error, but if you check the type() of img2, it'll return NoneType.

# %%
type(img2)
# Out:
# NoneType

# %%
img #numpy array
# Out:
# array([[[ 87, 102, 113],
#         [ 87, 102, 113],
#         [ 87, 102, 113],
#         ...,
#         [107, 126, 155],
#         [146, 165, 196],
#         [146, 165, 196]],
#
#        [[ 87, 102, 113],
#         [ 87, 102, 113],
#         [ 87, 102, 113],
#         ...,
#         [107, 126, 155],
#         [146, 165, 196],
#         [146, 165, 196]],
#
#        [[ 87, 102, 113],
#         [ 87, 102, 113],
#         [ 87, 102, 113],
#         ...,
#         [107, 126, 155],
#         [144, 163, 194],
#         [146, 165, 196]],
#
#        ...,
#
#        [[ 97, 109, 116],
#         [ 96, 107, 115],
#         [ 97, 109, 116],
#         ...,
#         [ 11,  15,  25],
#         [ 11,  15,  25],
#         [ 13,  16,  27]],
#
#        [[ 97, 109, 116],
#         [ 96, 107, 115],
#         [ 97, 109, 116],
#         ...,
#         [  8,  14,  24],
#         [ 11,  15,  25],
#         [ 11,  15,  25]],
#
#        [[ 97, 109, 116],
#         [ 96, 107, 115],
#         [ 97, 109, 116],
# ...

# %%
img.shape
# Out:
# (898, 898, 3)

# %%
plt.imshow(img)

# %% [markdown]
# * The above image has a blue tint over it.
# * This is because matplotlib and opencv have different orders of the R G B channels.
# * matplotlib --> R-G-B
# * OpenCV --> B-G-R
# **When imread reads a file, it reads it as BGR, but when plotting, matplotlib plots it as RGB. So the Red and Blue channels are getting swapped**
#
# We therefore need to transform this to go from BGR to RGB, the way matplotlib expects it.

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('jared.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (898, 898)

# %% [markdown]
# The above code doesn't output 3 because it only has one color channel now.

# %%
plt.imshow(img_gray,cmap='gray')
#We need to specify colour mapping

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (898, 898, 3)

# %%
#To resize:
new_img = cv2.resize(fix_img,(500,350))
#Takes a tuple as argument containing dimensions (width, height)

# %%
plt.imshow(new_img)

# %% [markdown]
# #### **Important Note: In NumPy, resolution is taken as (height, width). OpenCV follows the opposite convention where it takes resolution as (width, height)**

# %% [markdown]
# **Resize By ratio:**

# %%
w_ratio = 0.8
h_ratio=0.4

# %%
new_img=cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)
#The syntax for this is weird

# %%
plt.imshow(new_img)

# %% [markdown]
# ### Flip image horizontally and vertically:

# %%
flip_img=cv2.flip(fix_img,0) #0 --> Horizontal flip
plt.imshow(flip_img)

# %%
vflip_img=cv2.flip(fix_img,1) #1 --> Vertical fLip
plt.imshow(vflip_img)

# %% [markdown]
# ## Saving Images:

# %%
cv2.imwrite('jared_vflip.jpg',vflip_img.co)
#always remember to add file extension in the end.
# Out:
# True

# %%
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111)
ax.imshow(fix_img)
